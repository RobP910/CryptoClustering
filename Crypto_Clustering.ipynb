# %%
# Import required libraries and dependencies
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e6d046da-b58e-44c1-be36-41c215741634" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame and make the index the "coin_id" column.
market_data_df = pd.read_csv("Resources/crypto_market_data.csv", index_col="coin_id")

# Display sample data
market_data_df.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
market_data_df.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
numeric_data = market_data_df.select_dtypes(include=[float, int])
scaler = StandardScaler()
standardized_data = scaler.fit_transform(numeric_data)

# %%
# Create a DataFrame with the scaled data
standardized_df = pd.DataFrame(standardized_data, columns=numeric_data.columns, index=market_data_df.index)

# Copy the crypto names from the original data
# See previous step

# Set the coinid column as index
# See previous step

# Display sample data
display(standardized_df.head())
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
K = range(1,11)

# Create an empty list to store the inertia values
inertia_list = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
for k in K:
    # 1. Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=42)

    # 2. Fit the model to the data using the scaled DataFrame
    kmeans.fit(standardized_df)

    # 3. Append the model.inertia_ to the inertia list
    inertia_list.append(kmeans.inertia_)

# Create a dictionary with the data to plot the Elbow curve
elbow_data = {'k': K, 'inertia': inertia_list}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df = pd.DataFrame(elbow_data)

# Display the DataFrame
display(elbow_df)
# Out:
# C:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1426: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1426: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1426: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
plt.figure(figsize=(8, 6))
plt.plot(elbow_df['k'], elbow_df['inertia'], marker='*')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Finding the optimal k value')
plt.show()

# %% [markdown]
# #### Answer the following question:
# **Question:** What is the best value for `k`?
#
# **Answer:** 4

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled Data.

# %%
# Initialize the K-Means model using the best value for k
best_k = 4
kmeans_best = KMeans(n_clusters=best_k, random_state=42)

# %%
# Fit the K-Means model using the scaled data
kmeans_best.fit(standardized_df)
# Out:
# C:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1426: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
clusters = kmeans_best.predict(standardized_df)

# View the resulting array of cluster values.
print(clusters)
# Out:
# [0 0 2 2 0 0 0 0 0 2 2 2 2 0 2 0 2 2 0 2 2 0 2 2 2 2 2 2 0 2 2 2 3 0 2 2 1
#  2 2 2 2]

# %%
# Create a copy of the DataFrame
standardized_clusters = standardized_df.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
standardized_clusters['crypto_cluster'] = clusters

# Display sample data
display(standardized_clusters.head())
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using Pandas plot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Use "rainbow" for the color to better visualize the data.
# Plotting
ax = standardized_clusters.plot.scatter(x="price_change_percentage_24h", y="price_change_percentage_7d", c=standardized_clusters["price_change_percentage_24h"], cmap="viridis", figsize=(10, 6))

# Customizing labels and title
ax.set_xlabel("24h Price Change Percentage")
ax.set_ylabel("7d Price Change Percentage")
ax.set_title("Scatter Plot of Price Change Percentages")

# Show plot
plt.show()

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` on the original scaled DataFrame to reduce to three principal components.
pca_result = pca.fit_transform(standardized_df)

# View the first five rows of the array.
print(type(pca_result[:5]))
# Out:
# <class 'numpy.ndarray'>

# %%
# Retrieve the explained variance to determine how much information can be attributed to each principal component.
print(pca.explained_variance_ratio_)

total_variance = sum(pca.explained_variance_ratio_)
print(f"Total explained variance of the three principal components: {total_variance:.8f}")
# Out:
# [0.3719856  0.34700813 0.17603793]
# Total explained variance of the three principal components: 0.89503166

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** 0.89503166

# %%
# Create a new DataFrame with the PCA data.
# Note: The code for this step is provided for you

# Where?? I privided my own below...

# Creating a DataFrame with the PCA data
pca_data_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2', 'PC3'], index=market_data_df.index)
# Copy the crypto names from the original data
# Set the coinid column as index

# Display sample data
display("PCA Sample Data:")
display(pca_data_df.head(10))
# Out:
# 'PCA Sample Data:'
#                       PC1       PC2       PC3
# coin_id
# bitcoin         -0.600667  0.842760  0.461595
# ethereum        -0.458261  0.458466  0.952877
# tether          -0.433070 -0.168126 -0.641752
# ripple          -0.471835 -0.222660 -0.479053
# bitcoin-cash    -1.157800  2.041209  1.859715
# binancecoin     -0.516534  1.388377  0.804071
# chainlink       -0.450711  0.517699  2.846143
# cardano         -0.345600  0.729439  1.478013
# litecoin        -0.649468  0.432165  0.600303
# bitcoin-cash-sv -0.759014 -0.201200 -0.217653

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
pca_K = range(1,11)

# Create an empty list to store the inertia values
pca_inertia_list = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
for k in pca_K:
    # 1. Create a KMeans model using the loop counter for the n_clusters
    pca_kmeans = KMeans(n_clusters=k, random_state=42)

    # 2. Fit the model to the data using PCA DataFrame.
    pca_kmeans.fit(pca_data_df)

    # 3. Append the model.inertia_ to the inertia list
    pca_inertia_list.append(pca_kmeans.inertia_)

# Create a dictionary with the data to plot the Elbow curve
pca_data = {'k': pca_K, 'inertia': pca_inertia_list}

# Create a DataFrame with the data to plot the Elbow curve
pca_df = pd.DataFrame(pca_data)

# Display the DataFrame
display(pca_df)
# Out:
# C:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1426: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1426: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1426: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
plt.figure(figsize=(8, 6))
plt.plot(pca_df['k'], pca_df['inertia'], marker='*')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Finding the optimal k value')
plt.show()

# %% [markdown]
# #### Answer the following questions:
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
pca_k = 4
pca_kmeans_best = KMeans(n_clusters=pca_k, random_state=42)

# %%
# Fit the K-Means model using the PCA data
pca_kmeans_best.fit(pca_data_df)
# Out:
# C:\ProgramData\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1426: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
pca_clusters = pca_kmeans_best.predict(pca_data_df)

# View the resulting array of cluster values.
print(pca_clusters)
# Out:
# [0 0 2 2 0 0 0 0 0 2 2 2 2 0 2 0 2 2 0 2 2 0 2 2 2 2 2 2 0 2 2 2 3 0 2 2 1
#  2 2 2 2]

# %%
# Create a copy of the DataFrame with the PCA data
clustered_pca_clusters = pca_data_df.copy()

# Add a new column to the DataFrame with the predicted clusters
clustered_pca_clusters['crypto_cluster'] = pca_clusters

# Display sample data
display(clustered_pca_clusters.head())
# Out:
#                    PC1       PC2       PC3  crypto_cluster
# coin_id
# bitcoin      -0.600667  0.842760  0.461595               0
# ethereum     -0.458261  0.458466  0.952877               0
# tether       -0.433070 -0.168126 -0.641752               2
# ripple       -0.471835 -0.222660 -0.479053               2
# bitcoin-cash -1.157800  2.041209  1.859715               0

# %%
# Create a scatter plot using hvPlot by setting `x="PCA1"` and `y="PCA2"`. 
# scatter_plot = pca_data_df.hvplot.scatter(x="PC1", y="PC2")

# Show plot
# scatter_plot

tx = clustered_pca_clusters.plot.scatter(x="PC1", y="PC2", c=clustered_pca_clusters["crypto_cluster"], cmap='viridis', figsize=(7, 5))

# Customizing labels and title
tx.set_xlabel("PCA1")
tx.set_ylabel("PCA2")

# Show plot
plt.show()

# %% [markdown]
# ### Determine the Weights of Each Feature on each Principal Component

# %%
# Use the columns from the original scaled DataFrame as the index.
# Retrieve the weights of each feature for each principal component
weights = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2', 'PC3'], index=standardized_df.columns)

# Display the DataFrame
display(weights)
# Out:
#                                    PC1       PC2       PC3
# price_change_percentage_24h  -0.416728  0.358162 -0.218795
# price_change_percentage_7d   -0.102432  0.227432  0.787670
# price_change_percentage_14d  -0.009162  0.540415  0.349534
# price_change_percentage_30d   0.191523  0.562182 -0.181744
# price_change_percentage_60d   0.320365  0.434040 -0.361377
# price_change_percentage_200d  0.594468  0.027735  0.039733
# price_change_percentage_1y    0.568379 -0.150789  0.210541

# %% [markdown]
# #### Answer the following question:
#
# * **Question:** Which features have the strongest positive or negative influence on each component?
#
# * **Answer:**
# * PC1 / price_change_percentage_200d = 0.5945
# * PC2 / price_change_percentage_30d = 0.5622
# * PC3 / price_change_percentage_7d = 0.7877
